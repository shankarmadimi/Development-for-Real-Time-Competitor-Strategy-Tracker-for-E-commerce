# %%
import requests
import pandas as pd
import time
import re
from bs4 import BeautifulSoup
from difflib import SequenceMatcher

BASE_URL = "https://books.toscrape.com/"
CATALOGUE_URL = BASE_URL + "catalogue/page-{}.html"
GOOGLE_BOOKS_API = "https://www.googleapis.com/books/v1/volumes"
BOOKSRUN_API_KEY = "5xxn82dd5zz7hctfjf90"
BOOKSRUN_API_URL = "https://booksrun.com/api/v3/price/buy/{}?key={}"
HEADERS = {"User-Agent": "Mozilla/5.0"}

SIMILARITY_THRESHOLD = 0.7
SLEEP_TIME = 1.5
OUTPUT_FILE = "booksrun_price_comparison.csv"
TOTAL_PAGES = 50

def clean(text):
    return re.sub(r"[^a-z0-9 ]", "", text.lower()).strip()

def similarity(a, b):
    return SequenceMatcher(None, a, b).ratio()

def clean_price(price_text):
    return float(re.sub(r"[^\d.]", "", price_text))

#
def scrape_books():
    books = []
    for page in range(1, TOTAL_PAGES + 1):
        print(f"Scraping page {page}...")
        r = requests.get(CATALOGUE_URL.format(page), headers=HEADERS)
        if r.status_code != 200:
            continue

        soup = BeautifulSoup(r.text, "html.parser")
        for article in soup.select("article.product_pod"):
            title = article.h3.a["title"]
            price_text = article.select_one("p.price_color").text
            our_price = clean_price(price_text)

            books.append({
                "title": title,
                "our_price": our_price
            })

    print(f"Total books scraped: {len(books)}")
    return books


def google_books_search(title):
    params = {"q": f"intitle:{title}", "maxResults": 5}
    r = requests.get(GOOGLE_BOOKS_API, params=params, headers=HEADERS)
    if r.status_code != 200:
        return []
    return r.json().get("items", [])

def extract_isbn13(item):
    isbns = []
    for i in item.get("volumeInfo", {}).get("industryIdentifiers", []):
        if i.get("type") == "ISBN_13":
            isbns.append(i.get("identifier"))
    return isbns


def fetch_booksrun_prices(isbn):
    url = BOOKSRUN_API_URL.format(isbn, BOOKSRUN_API_KEY)
    try:
        r = requests.get(url, headers=HEADERS, timeout=10)
        data = r.json()

        if "result" not in data or "offers" not in data["result"]:
            return None

        offers = data["result"]["offers"]

        booksrun = offers.get("booksrun", {})
        if isinstance(booksrun, list):
            booksrun = booksrun[0] if booksrun else {}
        if not isinstance(booksrun, dict):
            booksrun = {}

        marketplace = offers.get("marketplace", {})
        if isinstance(marketplace, list):
            marketplace = marketplace[0] if marketplace else {}
        if not isinstance(marketplace, dict):
            marketplace = {}

        used_price = None
        used = booksrun.get("used")
        if isinstance(used, dict):
            used_price = used.get("price")

        new_price = booksrun.get("new")
        if not isinstance(new_price, (int, float)):
            new_price = None

        rental_price = booksrun.get("rent")
        if not isinstance(rental_price, (int, float)):
            rental_price = None

        marketplace_price = None
        market_used = marketplace.get("used")
        if isinstance(market_used, dict):
            marketplace_price = market_used.get("price")

        prices = [p for p in [used_price, new_price, rental_price, marketplace_price] if isinstance(p, (int, float))]
        if not prices:
            return None

        return {
            "isbn13": isbn,
            "competitor_price": min(prices),
            "used_price": used_price,
            "new_price": new_price,
            "rental_price": rental_price,
            "marketplace_price": marketplace_price
        }

    except Exception as e:
        print(f"BooksRun error for ISBN {isbn}: {e}")

    return None


def main():
    books = scrape_books()
    results = []
    seen_isbns = set()

    for idx, book in enumerate(books, 1):
        title = book["title"]
        our_price = book["our_price"]

        print(f"\nProcessing ({idx}/{len(books)}): {title}")
        clean_title_str = clean(title)

        google_items = google_books_search(title)
        for item in google_items:
            g_title = clean(item.get("volumeInfo", {}).get("title", ""))
            if similarity(clean_title_str, g_title) < SIMILARITY_THRESHOLD:
                continue

            binding = item.get("volumeInfo", {}).get("printType", "UNKNOWN")

            for isbn in extract_isbn13(item):
                if isbn in seen_isbns:
                    continue

                prices = fetch_booksrun_prices(isbn)
                if prices:
                    competitor_price = prices["competitor_price"]

                    # ===== MARKET-ADJUSTED PRICING STRATEGY (FIXED) =====
                    PERCENT_CHANGE = 0.05  # 5% undercut

                    if competitor_price > our_price:
                        # Competitor price higher → undercut competitor by 5%
                        action = "increase_price"
                        adjusted_price = round(competitor_price * (1 - PERCENT_CHANGE), 2)
                    else:
                        # Competitor price lower or equal → stay competitive
                        action = "reduce_price"
                        adjusted_price = round(competitor_price * (1 - PERCENT_CHANGE), 2)

                    profit = round(adjusted_price - our_price, 2)

                    results.append({
                        "title": title,
                        "binding": binding,
                        "our_price": our_price,
                        **prices,
                        "pricing_action": action,
                        "adjusted_price": adjusted_price,
                        "profit": profit
                    })

                    seen_isbns.add(isbn)
                    print(f"✔ PRICE FOUND → ISBN {isbn}")
                    break

        time.sleep(SLEEP_TIME)

    df = pd.DataFrame(results)
    df.to_csv(OUTPUT_FILE, index=False)

    print(f"\n✅ Finished!")
    print(f"✅ Total books with prices: {len(df)}")
    print(f"✅ CSV saved: {OUTPUT_FILE}")


if __name__ == "__main__":
    main()
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
# Scraping page 4...
# Scraping page 5...
# Scraping page 6...
# Scraping page 7...
# Scraping page 8...
# Scraping page 9...
# Scraping page 10...
# Scraping page 11...
# Scraping page 12...
# Scraping page 13...
# Scraping page 14...
# Scraping page 15...
# Scraping page 16...
# Scraping page 17...
# Scraping page 18...
# Scraping page 19...
# Scraping page 20...
# Scraping page 21...
# Scraping page 22...
# Scraping page 23...
# Scraping page 24...
# Scraping page 25...
# Scraping page 26...
# Scraping page 27...
# Scraping page 28...
# Scraping page 29...
# Scraping page 30...
# Scraping page 31...
# Scraping page 32...
# Scraping page 33...
# Scraping page 34...
# Scraping page 35...
# Scraping page 36...
# Scraping page 37...
# Scraping page 38...
# Scraping page 39...
# Scraping page 40...
# Scraping page 41...
# Scraping page 42...
# Scraping page 43...
# Scraping page 44...
# Scraping page 45...
# Scraping page 46...
# Scraping page 47...
# Scraping page 48...
# Scraping page 49...
# Scraping page 50...
# Total books scraped: 1000
#
# Processing (1/1000): A Light in the Attic
# ✔ PRICE FOUND → ISBN 9780061905858
#
# Processing (2/1000): Tipping the Velvet
#
# Processing (3/1000): Soumission
#
# Processing (4/1000): Sharp Objects
#
# Processing (5/1000): Sapiens: A Brief History of Humankind
#
# Processing (6/1000): The Requiem Red
#
# Processing (7/1000): The Dirty Little Secrets of Getting Your Dream Job
# ✔ PRICE FOUND → ISBN 9781942872764
#
# Processing (8/1000): The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull
#
# Processing (9/1000): The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics
#
# Processing (10/1000): The Black Maria
#
# Processing (11/1000): Starving Hearts (Triangular Trade Trilogy, #1)
#
# Processing (12/1000): Shakespeare's Sonnets
#
# Processing (13/1000): Set Me Free
#
# Processing (14/1000): Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)
#
# Processing (15/1000): Rip it Up and Start Again
# BooksRun error for ISBN 9791030414226: 'list' object has no attribute 'get'
#
# Processing (16/1000): Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991
#
# Processing (17/1000): Olio
#
# Processing (18/1000): Mesaerion: The Best Science Fiction Stories 1800-1849
#
# Processing (19/1000): Libertarianism for Beginners
#
# Processing (20/1000): It's Only the Himalayas
#
# Processing (21/1000): In Her Wake
#
# Processing (22/1000): How Music Works
# BooksRun error for ISBN 9798503293753: 'list' object has no attribute 'get'
#
# Processing (23/1000): Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More
#
# Processing (24/1000): Chase Me (Paris Nights #2)
#
# Processing (25/1000): Black Dust
#
# Processing (26/1000): Birdsong: A Story in Pictures
#
# Processing (27/1000): America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana
#
# Processing (28/1000): Aladdin and His Wonderful Lamp
#
# Processing (29/1000): Worlds Elsewhere: Journeys Around Shakespeareâs Globe
#
# Processing (30/1000): Wall and Piece
#
# Processing (31/1000): The Four Agreements: A Practical Guide to Personal Freedom
#
# Processing (32/1000): The Five Love Languages: How to Express Heartfelt Commitment to Your Mate
#
# Processing (33/1000): The Elephant Tree
#
# Processing (34/1000): The Bear and the Piano
#
# Processing (35/1000): Sophie's World
#
# Processing (36/1000): Penny Maybe
#
# Processing (37/1000): Maude (1883-1993):She Grew Up with the country
#
# Processing (38/1000): In a Dark, Dark Wood
# ✔ PRICE FOUND → ISBN 9781501112317
#
# Processing (39/1000): Behind Closed Doors
#
# Processing (40/1000): You can't bury them all: Poems
#
# Processing (41/1000): Slow States of Collapse: Poems
#
# Processing (42/1000): Reasons to Stay Alive
# ✔ PRICE FOUND → ISBN 9780143128724
# BooksRun error for ISBN 9798304625296: 'list' object has no attribute 'get'
#
# Processing (43/1000): Private Paris (Private #10)
#
# Processing (44/1000): #HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.
#
# Processing (45/1000): Without Borders (Wanderlove #1)
#
# Processing (46/1000): When We Collided
# BooksRun error for ISBN 9798311672580: 'list' object has no attribute 'get'
# ✔ PRICE FOUND → ISBN 9781681192031
#
# Processing (47/1000): We Love You, Charlie Freeman
# ✔ PRICE FOUND → ISBN 9781616206444
#
# Processing (48/1000): Untitled Collection: Sabbath Poems 2014
#
# Processing (49/1000): Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness
#
# Processing (50/1000): Unicorn Tracks
#
# Processing (51/1000): Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink
#
# Processing (52/1000): Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)
#
# Processing (53/1000): Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity
#
# Processing (54/1000): This One Summer
# ✔ PRICE FOUND → ISBN 9781596437746
# BooksRun error for ISBN 9798350753431: 'list' object has no attribute 'get'
#
# Processing (55/1000): Thirst
#
# Processing (56/1000): The Torch Is Passed: A Harding Family Story
#
# Processing (57/1000): The Secret of Dreadwillow Carse
#
# Processing (58/1000): The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!
#
# Processing (59/1000): The Past Never Ends
#
# Processing (60/1000): The Natural History of Us (The Fine Art of Pretending #2)
#
# Processing (61/1000): The Nameless City (The Nameless City #1)
#
# Processing (62/1000): The Murder That Never Was (Forensic Instincts #5)
#
# Processing (63/1000): The Most Perfect Thing: Inside (and Outside) a Bird's Egg
#
# Processing (64/1000): The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy
#
# Processing (65/1000): The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing
#
# Processing (66/1000): The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer
#
# Processing (67/1000): The Gutsy Girl: Escapades for Your Life of Epic Adventure
#
# Processing (68/1000): The Electric Pencil: Drawings from Inside State Hospital No. 3
#
# Processing (69/1000): The Death of Humanity: and the Case for Life
#
# Processing (70/1000): The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life
#
# Processing (71/1000): The Art Forger
# ✔ PRICE FOUND → ISBN 9781616201326
#
# Processing (72/1000): The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind
#
# Processing (73/1000): The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution
#
# Processing (74/1000): Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up
#
# Processing (75/1000): Soul Reader
# BooksRun error for ISBN 9798886531015: 'list' object has no attribute 'get'
#
# Processing (76/1000): Security
#
# Processing (77/1000): Saga, Volume 6 (Saga (Collected Editions) #6)
#
# Processing (78/1000): Saga, Volume 5 (Saga (Collected Editions) #5)
#
# Processing (79/1000): Reskilling America: Learning to Labor in the Twenty-First Century
#
# Processing (80/1000): Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)
#
# Processing (81/1000): Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)
#
# Processing (82/1000): Princess Between Worlds (Wide-Awake Princess #5)
#
# Processing (83/1000): Pop Gun War, Volume 1: Gift
#
# Processing (84/1000): Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics
#
# Processing (85/1000): Patience
#
# Processing (86/1000): Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)
#
# Processing (87/1000): orange: The Complete Collection 1 (orange: The Complete Collection #1)
#
# Processing (88/1000): Online Marketing for Busy Authors: A Step-By-Step Guide
#
# Processing (89/1000): On a Midnight Clear
# ✔ PRICE FOUND → ISBN 9781950054350
#
# Processing (90/1000): Obsidian (Lux #1)
#
# Processing (91/1000): My Paris Kitchen: Recipes and Stories
#
# Processing (92/1000): Masks and Shadows
#
# Processing (93/1000): Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed
#
# Processing (94/1000): Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)
#
# Processing (95/1000): Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)
#
# Processing (96/1000): Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)
#
# Processing (97/1000): Layered: Baking, Building, and Styling Spectacular Cakes
#
# Processing (98/1000): Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)
#
# Processing (99/1000): Join
#
# Processing (100/1000): In the Country We Love: My Family Divided
#
# Processing (101/1000): Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine
#
# Processing (102/1000): I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)
#
# Processing (103/1000): I am a Hero Omnibus Volume 1
#
# Processing (104/1000): How to Be Miserable: 40 Strategies You Already Use
#
# Processing (105/1000): Her Backup Boyfriend (The Sorensen Family #1)
#
# Processing (106/1000): Giant Days, Vol. 2 (Giant Days #5-8)
#
# Processing (107/1000): Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton
#
# Processing (108/1000): First and First (Five Boroughs #3)
#
# Processing (109/1000): Fifty Shades Darker (Fifty Shades #2)
#
# Processing (110/1000): Everydata: The Misinformation Hidden in the Little Data You Consume Every Day
#
# Processing (111/1000): Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master
#
# Processing (112/1000): Danganronpa Volume 1
# ✔ PRICE FOUND → ISBN 9781616559281
#
# Processing (113/1000): Crown of Midnight (Throne of Glass #2)
#
# Processing (114/1000): Codename Baboushka, Volume 1: The Conclave of Death
#
# Processing (115/1000): Camp Midnight
#
# Processing (116/1000): Call the Nurse: True Stories of a Country Nurse on a Scottish Isle
#
# Processing (117/1000): Burning
#
# Processing (118/1000): Bossypants
# ✔ PRICE FOUND → ISBN 9780316056861
#
# Processing (119/1000): Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))
#
# Processing (120/1000): Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)
# ✔ PRICE FOUND → ISBN 9781616557904
#
# Processing (121/1000): Algorithms to Live By: The Computer Science of Human Decisions
#
# Processing (122/1000): A World of Flavor: Your Gluten Free Passport
#
# Processing (123/1000): A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations
#
# Processing (124/1000): A Murder in Time
#
# Processing (125/1000): A Flight of Arrows (The Pathfinders #2)
#
# Processing (126/1000): A Fierce and Subtle Poison
#
# Processing (127/1000): A Court of Thorns and Roses (A Court of Thorns and Roses #1)
#
# Processing (128/1000): (Un)Qualified: How God Uses Broken People to Do Big Things
#
# Processing (129/1000): You Are What You Love: The Spiritual Power of Habit
#
# Processing (130/1000): William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)
# BooksRun error for ISBN 9798337401287: 'list' object has no attribute 'get'
#
# Processing (131/1000): Tuesday Nights in 1980
#
# Processing (132/1000): Tracing Numbers on a Train
#
# Processing (133/1000): Throne of Glass (Throne of Glass #1)
#
# Processing (134/1000): Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History
#
# Processing (135/1000): Thirteen Reasons Why
#
# Processing (136/1000): The White Cat and the Monk: A Retelling of the Poem âPangur BÃ¡nâ
#
# Processing (137/1000): The Wedding Dress
# ✔ PRICE FOUND → ISBN 9781595549631
# ✔ PRICE FOUND → ISBN 9780399179617
#
# Processing (138/1000): The Vacationers
#
# Processing (139/1000): The Third Wave: An Entrepreneurâs Vision of the Future
#
# Processing (140/1000): The Stranger
# ✔ PRICE FOUND → ISBN 9780395423318
# ✔ PRICE FOUND → ISBN 9781499727951
#
# Processing (141/1000): The Shadow Hero (The Shadow Hero)
#
# Processing (142/1000): The Secret (The Secret #1)
#
# Processing (143/1000): The Regional Office Is Under Attack!
# ✔ PRICE FOUND → ISBN 9781594632419
# ✔ PRICE FOUND → ISBN 9780399573217
#
# Processing (144/1000): The Psychopath Test: A Journey Through the Madness Industry
#
# Processing (145/1000): The Project
#
# Processing (146/1000): The Power of Now: A Guide to Spiritual Enlightenment
#
# Processing (147/1000): The Omnivore's Dilemma: A Natural History of Four Meals
#
# Processing (148/1000): The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us
#
# Processing (149/1000): The Murder of Roger Ackroyd (Hercule Poirot #4)
# ✔ PRICE FOUND → ISBN 9780425200476
#
# Processing (150/1000): The Mistake (Off-Campus #2)
#
# Processing (151/1000): The Matchmaker's Playbook (Wingmen Inc. #1)
#
# Processing (152/1000): The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking
#
# Processing (153/1000): The Long Shadow of Small Ghosts: Murder and Memory in an American City
#
# Processing (154/1000): The Kite Runner
# ✔ PRICE FOUND → ISBN 9781594489600
#
# Processing (155/1000): The House by the Lake
#
# Processing (156/1000): The Glittering Court (The Glittering Court #1)
#
# Processing (157/1000): The Girl on the Train
#
# Processing (158/1000): The Genius of Birds
# BooksRun error for ISBN 9798653608049: 'list' object has no attribute 'get'
#
# Processing (159/1000): The Emerald Mystery
#
# Processing (160/1000): The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First
#
# Processing (161/1000): The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs.
#
# Processing (162/1000): The Artist's Way: A Spiritual Path to Higher Creativity
#
# Processing (163/1000): The Art of War
# ✔ PRICE FOUND → ISBN 9780813319513
#
# Processing (164/1000): The Argonauts
# BooksRun error for ISBN 9798709349896: 'list' object has no attribute 'get'
#
# Processing (165/1000): The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job
#
# Processing (166/1000): Suddenly in Love (Lake Haven #1)
#
# Processing (167/1000): Something More Than This
#
# Processing (168/1000): Soft Apocalypse
#
# Processing (169/1000): So You've Been Publicly Shamed
# ✔ PRICE FOUND → ISBN 9781594634017
# BooksRun error for ISBN 9798822528543: 'list' object has no attribute 'get'
# ✔ PRICE FOUND → ISBN 9781594487132
#
# Processing (170/1000): Shoe Dog: A Memoir by the Creator of NIKE
#
# Processing (171/1000): Shobu Samurai, Project Aryoku (#3)
#
# Processing (172/1000): Secrets and Lace (Fatal Hearts #1)
#
# Processing (173/1000): Scarlett Epstein Hates It Here
# ✔ PRICE FOUND → ISBN 9781595148353
#
# Processing (174/1000): Romero and Juliet: A Tragic Tale of Love and Zombies
#
# Processing (175/1000): Redeeming Love
# ✔ PRICE FOUND → ISBN 9781590525135
# ✔ PRICE FOUND → ISBN 9780525654346
#
# Processing (176/1000): Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form
#
# Processing (177/1000): Poems That Make Grown Women Cry
# ✔ PRICE FOUND → ISBN 9781476712772
#
# Processing (178/1000): Nightingale, Sing
#
# Processing (179/1000): Night Sky with Exit Wounds
#
# Processing (180/1000): Mrs. Houdini
#
# Processing (181/1000): Modern Romance
# ✔ PRICE FOUND → ISBN 9780143109259
#
# Processing (182/1000): Miss Peregrineâs Home for Peculiar Children (Miss Peregrineâs Peculiar Children #1)
#
# Processing (183/1000): Louisa: The Extraordinary Life of Mrs. Adams
#
# Processing (184/1000): Little Red
#
# Processing (185/1000): Library of Souls (Miss Peregrineâs Peculiar Children #3)
#
# Processing (186/1000): Large Print Heart of the Pride
#
# Processing (187/1000): I Had a Nice Time And Other Lies...: How to find love & sh*t like that
#
# Processing (188/1000): Hollow City (Miss Peregrineâs Peculiar Children #2)
#
# Processing (189/1000): Grumbles
#
# Processing (190/1000): Full Moon over Noahâs Ark: An Odyssey to Mount Ararat and Beyond
#
# Processing (191/1000): Frostbite (Vampire Academy #2)
#
# Processing (192/1000): Follow You Home
#
# Processing (193/1000): First Steps for New Christians (Print Edition)
# ✔ PRICE FOUND → ISBN 9781598940633
#
# Processing (194/1000): Finders Keepers (Bill Hodges Trilogy #2)
#
# Processing (195/1000): Fables, Vol. 1: Legends in Exile (Fables #1)
#
# Processing (196/1000): Eureka Trivia 6.0
#
# Processing (197/1000): Drive: The Surprising Truth About What Motivates Us
#
# Processing (198/1000): Done Rubbed Out (Reightman & Bailey #1)
#
# Processing (199/1000): Doing It Over (Most Likely To #1)
#
# Processing (200/1000): Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals
#
# Processing (201/1000): Dark Notes
# BooksRun error for ISBN 9798603487625: 'list' object has no attribute 'get'
#
# Processing (202/1000): Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead
#
# Processing (203/1000): Close to You
#
# Processing (204/1000): Chasing Heaven: What Dying Taught Me About Living
#
# Processing (205/1000): Big Magic: Creative Living Beyond Fear
#
# Processing (206/1000): Becoming Wise: An Inquiry into the Mystery and Art of Living
#
# Processing (207/1000): Beauty Restored (Riley Family Legacy Novellas #3)
#
# Processing (208/1000): Batman: The Long Halloween (Batman)
#
# Processing (209/1000): Batman: The Dark Knight Returns (Batman)
#
# Processing (210/1000): Ayumi's Violin
#
# Processing (211/1000): Anonymous
#
# Processing (212/1000): Amy Meets the Saints and Sages
#
# Processing (213/1000): Amid the Chaos
# BooksRun error for ISBN 9798652907914: 'list' object has no attribute 'get'
# BooksRun error for ISBN 9798752804168: 'list' object has no attribute 'get'
#
# Processing (214/1000): Amatus
#
# Processing (215/1000): Agnostic: A Spirited Manifesto
#
# Processing (216/1000): Zealot: The Life and Times of Jesus of Nazareth
# ✔ PRICE FOUND → ISBN 9781400066926
#
# Processing (217/1000): You (You #1)
#
# Processing (218/1000): Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)
#
# Processing (219/1000): Wild Swans
# ✔ PRICE FOUND → ISBN 9780743246989
#
# Processing (220/1000): Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond
#
# Processing (221/1000): Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity
#
# Processing (222/1000): What's It Like in Space?: Stories from Astronauts Who've Been There
#
# Processing (223/1000): We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1)
#
# Processing (224/1000): Walt Disney's Alice in Wonderland
#
# Processing (225/1000): V for Vendetta (V for Vendetta Complete)
#
# Processing (226/1000): Until Friday Night (The Field Party #1)
#
# Processing (227/1000): Unbroken: A World War II Story of Survival, Resilience, and Redemption
#
# Processing (228/1000): Twenty Yawns
#
# Processing (229/1000): Through the Woods
#
# Processing (230/1000): This Is Where It Ends
#
# Processing (231/1000): The Year of Magical Thinking
# ✔ PRICE FOUND → ISBN 9781400043149
#
# Processing (232/1000): The Wright Brothers
#
# Processing (233/1000): The White Queen (The Cousins' War #1)
#
# Processing (234/1000): The Wedding Pact (The O'Malleys #2)
#
# Processing (235/1000): The Time Keeper
#
# Processing (236/1000): The Testament of Mary
# ✔ PRICE FOUND → ISBN 9781451688382
#
# Processing (237/1000): The Star-Touched Queen
# ✔ PRICE FOUND → ISBN 9781250085474
#
# Processing (238/1000): The Songs of the Gods
#
# Processing (239/1000): The Song of Achilles
#
# Processing (240/1000): The Rosie Project (Don Tillman #1)
#
# Processing (241/1000): The Power of Habit: Why We Do What We Do in Life and Business
#
# Processing (242/1000): The Marriage of Opposites
# ✔ PRICE FOUND → ISBN 9781628996777
#
# Processing (243/1000): The Lucifer Effect: Understanding How Good People Turn Evil
#
# Processing (244/1000): The Long Haul (Diary of a Wimpy Kid #9)
#
# Processing (245/1000): The Loney
#
# Processing (246/1000): The Literature Book (Big Ideas Simply Explained)
#
# Processing (247/1000): The Last Mile (Amos Decker #2)
#
# Processing (248/1000): The Immortal Life of Henrietta Lacks
# ✔ PRICE FOUND → ISBN 9781400052172
# BooksRun error for ISBN 9798684305986: 'list' object has no attribute 'get'
#
# Processing (249/1000): The Hidden Oracle (The Trials of Apollo #1)
#
# Processing (250/1000): The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes Kids Can Make to Stay Healthy and Save the Earth
#
# Processing (251/1000): The Guilty (Will Robie #4)
#
# Processing (252/1000): The First Hostage (J.B. Collins #2)
#
# Processing (253/1000): The Dovekeepers
# ✔ PRICE FOUND → ISBN 9781620900017
#
# Processing (254/1000): The Darkest Lie
#
# Processing (255/1000): The Bane Chronicles (The Bane Chronicles #1-11)
#
# Processing (256/1000): The Bad-Ass Librarians of Timbuktu: And Their Race to Save the Worldâs Most Precious Manuscripts
#
# Processing (257/1000): The 14th Colony (Cotton Malone #11)
#
# Processing (258/1000): That Darkness (Gardiner and Renner #1)
#
# Processing (259/1000): Tastes Like Fear (DI Marnie Rome #3)
#
# Processing (260/1000): Take Me with You
# ✔ PRICE FOUND → ISBN 9781416559511
#
# Processing (261/1000): Swell: A Year of Waves
#
# Processing (262/1000): Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)
#
# Processing (263/1000): Still Life with Bread Crumbs
# ✔ PRICE FOUND → ISBN 9781400065752
#
# Processing (264/1000): Steve Jobs
# ✔ PRICE FOUND → ISBN 9780761319597
# BooksRun error for ISBN 9798216149279: 'list' object has no attribute 'get'
#
# Processing (265/1000): Sorting the Beef from the Bull: The Science of Food Fraud Forensics
#
# Processing (266/1000): Someone Like You (The Harrisons #2)
#
# Processing (267/1000): So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)
#
# Processing (268/1000): Shtum
#
# Processing (269/1000): See America: A Celebration of Our National Parks & Treasured Sites
#
# Processing (270/1000): salt.
#
# Processing (271/1000): Robin War
#
# Processing (272/1000): Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsenal #1)
#
# Processing (273/1000): Rain Fish
#
# Processing (274/1000): Quarter Life Poetry: Poems for the Young, Broke and Hangry
#
# Processing (275/1000): Pet Sematary
#
# Processing (276/1000): Overload: How to Unplug, Unwind, and Unleash Yourself from the Pressure of Stress
#
# Processing (277/1000): Once Was a Time
#
# Processing (278/1000): Old School (Diary of a Wimpy Kid #10)
# ✔ PRICE FOUND → ISBN 9781419741968
#
# Processing (279/1000): No Dream Is Too High: Life Lessons From a Man Who Walked on the Moon
#
# Processing (280/1000): Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 (Naruto: Omnibus #14)
#
# Processing (281/1000): My Name Is Lucy Barton
#
# Processing (282/1000): My Mrs. Brown
#
# Processing (283/1000): My Kind of Crazy
#
# Processing (284/1000): Mr. Mercedes (Bill Hodges Trilogy #1)
#
# Processing (285/1000): More Than Music (Chasing the Dream #1)
#
# Processing (286/1000): Made to Stick: Why Some Ideas Survive and Others Die
# BooksRun error for ISBN 9798464278806: 'list' object has no attribute 'get'
#
# Processing (287/1000): Luis Paints the World
#
# Processing (288/1000): Luckiest Girl Alive
#
# Processing (289/1000): Lowriders to the Center of the Earth (Lowriders in Space #2)
#
# Processing (290/1000): Love Is a Mix Tape (Music #1)
# BooksRun error for ISBN 9791254801062: 'list' object has no attribute 'get'
#
# Processing (291/1000): Looking for Lovely: Collecting the Moments that Matter
#
# Processing (292/1000): Living Leadership by Insight: A Good Leader Achieves, a Great Leader Builds Monuments
#
# Processing (293/1000): Let It Out: A Journey Through Journaling
#
# Processing (294/1000): Lady Midnight (The Dark Artifices #1)
#
# Processing (295/1000): It's All Easy: Healthy, Delicious Weeknight Meals in under 30 Minutes
#
# Processing (296/1000): Island of Dragons (Unwanteds #7)
#
# Processing (297/1000): I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction
#
# Processing (298/1000): I Am Pilgrim (Pilgrim #1)
#
# Processing (299/1000): Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened
#
# Processing (300/1000): Hush, Hush (Hush, Hush #1)
#
# Processing (301/1000): Hold Your Breath (Search and Rescue #1)
#
# Processing (302/1000): Hamilton: The Revolution
#
# Processing (303/1000): Greek Mythic History
#
# Processing (304/1000): God: The Most Unpleasant Character in All Fiction
#
# Processing (305/1000): Glory over Everything: Beyond The Kitchen House
#
# Processing (306/1000): Feathers: Displays of Brilliant Plumage
#
# Processing (307/1000): Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years
#
# Processing (308/1000): Every Last Word
#
# Processing (309/1000): Eligible (The Austen Project #4)
#
# Processing (310/1000): El Deafo
#
# Processing (311/1000): Eight Hundred Grapes
#
# Processing (312/1000): Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life
#
# Processing (313/1000): Eat Fat, Get Thin
# ✔ PRICE FOUND → ISBN 9781473631168
#
# Processing (314/1000): Don't Get Caught
#
# Processing (315/1000): Doctor Sleep (The Shining #2)
#
# Processing (316/1000): Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3)
#
# Processing (317/1000): Dear Mr. Knightley
#
# Processing (318/1000): Daily Fantasy Sports
# BooksRun error for ISBN 9798598270530: 'list' object has no attribute 'get'
#
# Processing (319/1000): Crazy Love: Overwhelmed by a Relentless God
#
# Processing (320/1000): Cometh the Hour (The Clifton Chronicles #6)
#
# Processing (321/1000): Code Name Verity (Code Name Verity #1)
#
# Processing (322/1000): Clockwork Angel (The Infernal Devices #1)
#
# Processing (323/1000): City of Glass (The Mortal Instruments #3)
#
# Processing (324/1000): City of Fallen Angels (The Mortal Instruments #4)
#
# Processing (325/1000): City of Bones (The Mortal Instruments #1)
#
# Processing (326/1000): City of Ashes (The Mortal Instruments #2)
#
# Processing (327/1000): Cell
#
# Processing (328/1000): Catching Jordan (Hundred Oaks)
#
# Processing (329/1000): Carry On, Warrior: Thoughts on Life Unarmed
#
# Processing (330/1000): Carrie
#
# Processing (331/1000): Buying In: The Secret Dialogue Between What We Buy and Who We Are
#
# Processing (332/1000): Brain on Fire: My Month of Madness
#
# Processing (333/1000): Batman: Europa
#
# Processing (334/1000): Barefoot Contessa Back to Basics
#
# Processing (335/1000): Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again
#
# Processing (336/1000): Balloon Animals
# ✔ PRICE FOUND → ISBN 9780809245932
#
# Processing (337/1000): Art Ops Vol. 1
#
# Processing (338/1000): Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe #1)
#
# Processing (339/1000): Angels Walking (Angels Walking #1)
#
# Processing (340/1000): Angels & Demons (Robert Langdon #1)
#
# Processing (341/1000): All the Light We Cannot See
# ✔ PRICE FOUND → ISBN 9781476746586
#
# Processing (342/1000): Adulthood Is a Myth: A "Sarah's Scribbles" Collection
#
# Processing (343/1000): Abstract City
#
# Processing (344/1000): A Time of Torment (Charlie Parker #14)
#
# Processing (345/1000): A Study in Scarlet (Sherlock Holmes #1)
# BooksRun error for ISBN 9798595380669: 'list' object has no attribute 'get'
# BooksRun error for ISBN 9798593437167: 'list' object has no attribute 'get'
# BooksRun error for ISBN 9798717285469: 'list' object has no attribute 'get'
#
# Processing (346/1000): A Series of Catastrophes and Miracles: A True Story of Love, Science, and Cancer
#
# Processing (347/1000): A People's History of the United States
# ✔ PRICE FOUND → ISBN 9781565848269
# ✔ PRICE FOUND → ISBN 9780060528423
# ✔ PRICE FOUND → ISBN 9780060937317
#
# Processing (348/1000): A Man Called Ove
# ✔ PRICE FOUND → ISBN 9781668010815
#
# Processing (349/1000): A Distant Mirror: The Calamitous 14th Century
#
# Processing (350/1000): A Brush of Wings (Angels Walking #3)
#
# Processing (351/1000): 1491: New Revelations of the Americas Before Columbus
#
# Processing (352/1000): The Three Searches, Meaning, and the Story
#
# Processing (353/1000): Searching for Meaning in Gailana
#
# Processing (354/1000): Rook
#
# Processing (355/1000): My Kitchen Year: 136 Recipes That Saved My Life
#
# Processing (356/1000): 13 Hours: The Inside Account of What Really Happened In Benghazi
#
# Processing (357/1000): Will You Won't You Want Me?
#
# Processing (358/1000): Tipping Point for Planet Earth: How Close Are We to the Edge?
#
# Processing (359/1000): The Star-Touched Queen
#
# Processing (360/1000): The Silent Sister (Riley MacPherson #1)
#
# Processing (361/1000): The Midnight Watch: A Novel of the Titanic and the Californian
#
# Processing (362/1000): The Lonely City: Adventures in the Art of Being Alone
#
# Processing (363/1000): The Gray Rhino: How to Recognize and Act on the Obvious Dangers We Ignore
#
# Processing (364/1000): The Golden Condom: And Other Essays on Love Lost and Found
#
# Processing (365/1000): The Epidemic (The Program 0.6)
#
# Processing (366/1000): The Dinner Party
# ✔ PRICE FOUND → ISBN 9781250007872
#
# Processing (367/1000): The Diary of a Young Girl
#
# Processing (368/1000): The Children
#
# Processing (369/1000): Stars Above (The Lunar Chronicles #4.5)
#
# Processing (370/1000): Snatched: How A Drug Queen Went Undercover for the DEA and Was Kidnapped By Colombian Guerillas
#
# Processing (371/1000): Raspberry Pi Electronics Projects for the Evil Genius
#
# Processing (372/1000): Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two
#
# Processing (373/1000): Psycho: Sanitarium (Psycho #1.5)
#
# Processing (374/1000): Poisonous (Max Revere Novels #3)
#
# Processing (375/1000): One with You (Crossfire #5)
#
# Processing (376/1000): No Love Allowed (Dodge Cove #1)
#
# Processing (377/1000): Murder at the 42nd Street Library (Raymond Ambler #1)
#
# Processing (378/1000): Most Wanted
#
# Processing (379/1000): Love, Lies and Spies
# ✔ PRICE FOUND → ISBN 9781644681343
#
# Processing (380/1000): How to Speak Golf: An Illustrated Guide to Links Lingo
#
# Processing (381/1000): Hide Away (Eve Duncan #20)
#
# Processing (382/1000): Furiously Happy: A Funny Book About Horrible Things
#
# Processing (383/1000): Everyday Italian: 125 Simple and Delicious Recipes
#
# Processing (384/1000): Equal Is Unfair: America's Misguided Fight Against Income Inequality
#
# Processing (385/1000): Eleanor & Park
# ✔ PRICE FOUND → ISBN 9783423626392
#
# Processing (386/1000): Dirty (Dive Bar #1)
#
# Processing (387/1000): Can You Keep a Secret? (Fear Street Relaunch #4)
#
# Processing (388/1000): Boar Island (Anna Pigeon #19)
#
# Processing (389/1000): A Paris Apartment
# ✔ PRICE FOUND → ISBN 9780063252110
#
# Processing (390/1000): A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, and More Topped with Ice Cream, Gelato, Frozen Custard, and More
#
# Processing (391/1000): Troublemaker: Surviving Hollywood and Scientology
#
# Processing (392/1000): The Widow
#
# Processing (393/1000): The Sleep Revolution: Transforming Your Life, One Night at a Time
#
# Processing (394/1000): The Improbability of Love
# ✔ PRICE FOUND → ISBN 9781101872574
# ✔ PRICE FOUND → ISBN 9781101874141
# BooksRun error for ISBN 9798271428487: 'list' object has no attribute 'get'
#
# Processing (395/1000): The Art of Startup Fundraising
# BooksRun error for ISBN 9798300432638: 'list' object has no attribute 'get'
#
# Processing (396/1000): Take Me Home Tonight (Rock Star Romance #3)
#
# Processing (397/1000): Sleeping Giants (Themis Files #1)
#
# Processing (398/1000): Setting the World on Fire: The Brief, Astonishing Life of St. Catherine of Siena
#
# Processing (399/1000): Playing with Fire
#
# Processing (400/1000): Off the Hook (Fishing for Trouble #1)
#
# Processing (401/1000): Mothering Sunday
#
# Processing (402/1000): Mother, Can You Not?
#
# Processing (403/1000): M Train
#
# Processing (404/1000): Lilac Girls
#
# Processing (405/1000): Lies and Other Acts of Love
#
# Processing (406/1000): Lab Girl
#
# Processing (407/1000): Keep Me Posted
# BooksRun error for ISBN 9798391788850: 'list' object has no attribute 'get'
#
# Processing (408/1000): It Didn't Start with You: How Inherited Family Trauma Shapes Who We Are and How to End the Cycle
#
# Processing (409/1000): Grey (Fifty Shades #4)
#
# Processing (410/1000): Exit, Pursued by a Bear
#
# Processing (411/1000): Daredevils
# ✔ PRICE FOUND → ISBN 9781101979891
#
# Processing (412/1000): Cravings: Recipes for What You Want to Eat
#
# Processing (413/1000): Born for This: How to Find the Work You Were Meant to Do
#
# Processing (414/1000): Arena
#
# Processing (415/1000): Adultery
#
# Processing (416/1000): A Mother's Reckoning: Living in the Aftermath of Tragedy
#
# Processing (417/1000): A Gentleman's Position (Society of Gentlemen #3)
#
# Processing (418/1000): 11/22/63
# ✔ PRICE FOUND → ISBN 9781451627299
#
# Processing (419/1000): 10% Happier: How I Tamed the Voice in My Head, Reduced Stress Without Losing My Edge, and Found Self-Help That Actually Works
#
# Processing (420/1000): 10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!
#
# Processing (421/1000): Without Shame
#
# Processing (422/1000): Watchmen
# ✔ PRICE FOUND → ISBN 9781852860240
#
# Processing (423/1000): Unlimited Intuition Now
#
# Processing (424/1000): Underlying Notes
#
# Processing (425/1000): The Shack
# ✔ PRICE FOUND → ISBN 9781609414115
#
# Processing (426/1000): The New Brand You: Your New Image Makes the Sale for You
#
# Processing (427/1000): The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York
#
# Processing (428/1000): The Flowers Lied
#
# Processing (429/1000): The Fabric of the Cosmos: Space, Time, and the Texture of Reality
#
# Processing (430/1000): The Book of Mormon
#
# Processing (431/1000): The Art and Science of Low Carbohydrate Living
# ✔ PRICE FOUND → ISBN 9780983490708
# ✔ PRICE FOUND → ISBN 9780983490715
#
# Processing (432/1000): The Alien Club
#
# Processing (433/1000): Suzie Snowflake: One beautiful flake (a self-esteem story)
#
# Processing (434/1000): Nap-a-Roo
#
# Processing (435/1000): NaNo What Now? Finding your editing process, revising your NaNoWriMo book and building a writing career through publishing and beyond
#
# Processing (436/1000): Modern Day Fables
# BooksRun error for ISBN 9791041849918: 'list' object has no attribute 'get'
#
# Processing (437/1000): If I Gave You God's Phone Number....: Searching for Spirituality in America
#
# Processing (438/1000): Fruits Basket, Vol. 9 (Fruits Basket #9)
#
# Processing (439/1000): Dress Your Family in Corduroy and Denim
#
# Processing (440/1000): Don't Forget Steven
#
# Processing (441/1000): Chernobyl 01:23:40: The Incredible True Story of the World's Worst Nuclear Disaster
#
# Processing (442/1000): Art and Fear: Observations on the Perils (and Rewards) of Artmaking
#
# Processing (443/1000): A Shard of Ice (The Black Symphony Saga #1)
#
# Processing (444/1000): A Hero's Curse (The Unseen Chronicles #1)
#
# Processing (445/1000): 23 Degrees South: A Tropical Tale of Changing Whether...
#
# Processing (446/1000): Zero to One: Notes on Startups, or How to Build the Future
#
# Processing (447/1000): Why Not Me?
#
# Processing (448/1000): When Breath Becomes Air
# ✔ PRICE FOUND → ISBN 9780812988406
#
# Processing (449/1000): Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel
#
# Processing (450/1000): The Unlikely Pilgrimage of Harold Fry (Harold Fry #1)
#
# Processing (451/1000): The New Drawing on the Right Side of the Brain
# ✔ PRICE FOUND → ISBN 9781585421954
#
# Processing (452/1000): The Midnight Assassin: Panic, Scandal, and the Hunt for America's First Serial Killer
#
# Processing (453/1000): The Martian (The Martian #1)
#
# Processing (454/1000): The High Mountains of Portugal
#
# Processing (455/1000): The Grownup
#
# Processing (456/1000): The E-Myth Revisited: Why Most Small Businesses Don't Work and What to Do About It
#
# Processing (457/1000): South of Sunshine
#
# Processing (458/1000): Smarter Faster Better: The Secrets of Being Productive in Life and Business
#
# Processing (459/1000): Silence in the Dark (Logan Point #4)
#
# Processing (460/1000): Shadows of the Past (Logan Point #1)
#
# Processing (461/1000): Roller Girl
# ✔ PRICE FOUND → ISBN 9780803740167
#
# Processing (462/1000): Rising Strong
# ✔ PRICE FOUND → ISBN 9780812985801
#
# Processing (463/1000): Proofs of God: Classical Arguments from Tertullian to Barth
#
# Processing (464/1000): Please Kill Me: The Uncensored Oral History of Punk
#
# Processing (465/1000): Out of Print: City Lights Spotlight No. 14
#
# Processing (466/1000): My Life Next Door (My Life Next Door )
#
# Processing (467/1000): Miller's Valley
#
# Processing (468/1000): Man's Search for Meaning
# ✔ PRICE FOUND → ISBN 9780671023379
#
# Processing (469/1000): Love That Boy: What Two Presidents, Eight Road Trips, and My Son Taught Me About a Parent's Expectations
#
# Processing (470/1000): Living Forward: A Proven Plan to Stop Drifting and Get the Life You Want
#
# Processing (471/1000): Les Fleurs du Mal
#
# Processing (472/1000): Left Behind (Left Behind #1)
#
# Processing (473/1000): Kill 'Em and Leave: Searching for James Brown and the American Soul
#
# Processing (474/1000): Kierkegaard: A Christian Missionary to Christians
#
# Processing (475/1000): John Vassos: Industrial Design for Modern Life
#
# Processing (476/1000): I'll Give You the Sun
# ✔ PRICE FOUND → ISBN 9780142425763
# ✔ PRICE FOUND → ISBN 9786073812887
#
# Processing (477/1000): I Will Find You
#
# Processing (478/1000): Hystopia: A Novel
#
# Processing (479/1000): Howl and Other Poems
# ✔ PRICE FOUND → ISBN 9780872860179
# ✔ PRICE FOUND → ISBN 9780872863101
#
# Processing (480/1000): History of Beauty
#
# Processing (481/1000): Heaven is for Real: A Little Boy's Astounding Story of His Trip to Heaven and Back
#
# Processing (482/1000): Future Shock (Future Shock #1)
#
# Processing (483/1000): Ender's Game (The Ender Quintet #1)
#
# Processing (484/1000): Diary of a Citizen Scientist: Chasing Tiger Beetles and Other New Ways of Engaging the World
#
# Processing (485/1000): Death by Leisure: A Cautionary Tale
#
# Processing (486/1000): Brilliant Beacons: A History of the American Lighthouse
#
# Processing (487/1000): Brazen: The Courage to Find the You That's Been Hiding
#
# Processing (488/1000): Between the World and Me
#
# Processing (489/1000): Being Mortal: Medicine and What Matters in the End
#
# Processing (490/1000): A Murder Over a Girl: Justice, Gender, Junior High
#
# Processing (491/1000): 32 Yolks
#
# Processing (492/1000): "Most Blessed of the Patriarchs": Thomas Jefferson and the Empire of the Imagination
#
# Processing (493/1000): You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life
#
# Processing (494/1000): Wildlife of New York: A Five-Borough Coloring Book
# ✔ PRICE FOUND → ISBN 9780789212559
#
# Processing (495/1000): What Happened on Beale Street (Secrets of the South Mysteries #2)
#
# Processing (496/1000): Unreasonable Hope: Finding Faith in the God Who Brings Purpose to Your Pain
#
# Processing (497/1000): Under the Tuscan Sun
#
# Processing (498/1000): Toddlers Are A**holes: It's Not Your Fault
#
# Processing (499/1000): The Year of Living Biblically: One Man's Humble Quest to Follow the Bible as Literally as Possible
#
# Processing (500/1000): The Whale
# ✔ PRICE FOUND → ISBN 9780573701665
#
# Processing (501/1000): The Story of Art
# ✔ PRICE FOUND → ISBN 9781838668242
#
# Processing (502/1000): The Origin of Species
# ✔ PRICE FOUND → ISBN 9781784873622
#
# Processing (503/1000): The Great Gatsby
#
# Processing (504/1000): The Good Girl
# ✔ PRICE FOUND → ISBN 9780778317760
#
# Processing (505/1000): The Glass Castle
#
# Processing (506/1000): The Faith of Christopher Hitchens: The Restless Soul of the World's Most Notorious Atheist
#
# Processing (507/1000): The Drowning Girls
#
# Processing (508/1000): The Constant Princess (The Tudor Court #1)
#
# Processing (509/1000): The Bourne Identity (Jason Bourne #1)
# ✔ PRICE FOUND → ISBN 9780553260113
#
# Processing (510/1000): The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)
#
# Processing (511/1000): The Art Book
#
# Processing (512/1000): The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change
#
# Processing (513/1000): Team of Rivals: The Political Genius of Abraham Lincoln
#
# Processing (514/1000): Steal Like an Artist: 10 Things Nobody Told You About Being Creative
#
# Processing (515/1000): Sit, Stay, Love
#
# Processing (516/1000): Sister Dear
#
# Processing (517/1000): Shrunken Treasures: Literary Classics, Short, Sweet, and Silly
#
# Processing (518/1000): Rich Dad, Poor Dad
#
# Processing (519/1000): Raymie Nightingale
#
# Processing (520/1000): Playing from the Heart
# ✔ PRICE FOUND → ISBN 9780763678920
# ✔ PRICE FOUND → ISBN 9781558742536
# ✔ PRICE FOUND → ISBN 9781338188455
#
# Processing (521/1000): Nightstruck: A Novel
#
# Processing (522/1000): Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based Recipes--All Under 300 Calories
#
# Processing (523/1000): Meternity
#
# Processing (524/1000): Memoirs of a Geisha
# ✔ PRICE FOUND → ISBN 9781557046833
#
# Processing (525/1000): Like Never Before (Walker Family #2)
#
# Processing (526/1000): Life of Pi
# ✔ PRICE FOUND → ISBN 9780151008117
#
# Processing (527/1000): Leave This Song Behind: Teen Poetry at Its Best
#
# Processing (528/1000): King's Folly (The Kinsman Chronicles #1)
#
# Processing (529/1000): John Adams
# ✔ PRICE FOUND → ISBN 9781416575887
#
# Processing (530/1000): How to Cook Everything Vegetarian: Simple Meatless Recipes for Great Food (How to Cook Everything)
#
# Processing (531/1000): How to Be a Domestic Goddess: Baking and the Art of Comfort Cooking
#
# Processing (532/1000): Good in Bed (Cannie Shapiro #1)
#
# Processing (533/1000): Fruits Basket, Vol. 7 (Fruits Basket #7)
#
# Processing (534/1000): For the Love: Fighting for Grace in a World of Impossible Standards
#
# Processing (535/1000): Finding God in the Ruins: How God Redeems Pain
#
# Processing (536/1000): Every Heart a Doorway (Every Heart A Doorway #1)
#
# Processing (537/1000): Delivering the Truth (Quaker Midwife Mystery #1)
#
# Processing (538/1000): Counted With the Stars (Out from Egypt #1)
#
# Processing (539/1000): Chronicles, Vol. 1
# BooksRun error for ISBN 9798513505587: 'list' object has no attribute 'get'
#
# Processing (540/1000): Blue Like Jazz: Nonreligious Thoughts on Christian Spirituality
#
# Processing (541/1000): Benjamin Franklin: An American Life
#
# Processing (542/1000): At The Existentialist CafÃ©: Freedom, Being, and apricot cocktails with: Jean-Paul Sartre, Simone de Beauvoir, Albert Camus, Martin Heidegger, Edmund Husserl, Karl Jaspers, Maurice Merleau-Ponty and others
#
# Processing (543/1000): A Summer In Europe
#
# Processing (544/1000): A Short History of Nearly Everything
#
# Processing (545/1000): A Gathering of Shadows (Shades of Magic #2)
#
# Processing (546/1000): The Sound Of Love
#
# Processing (547/1000): The Rise and Fall of the Third Reich: A History of Nazi Germany
#
# Processing (548/1000): The Perks of Being a Wallflower
# ✔ PRICE FOUND → ISBN 9781451696196
#
# Processing (549/1000): The Mysterious Affair at Styles (Hercule Poirot #1)
# BooksRun error for ISBN 9798649240376: 'list' object has no attribute 'get'
# BooksRun error for ISBN 9798538777723: 'list' object has no attribute 'get'
#
# Processing (550/1000): The Man Who Mistook His Wife for a Hat and Other Clinical Tales
# ✔ PRICE FOUND → ISBN 9780684853949
#
# Processing (551/1000): The Makings of a Fatherless Child
# ✔ PRICE FOUND → ISBN 9781720556398
#
# Processing (552/1000): The Joy of Cooking
#
# Processing (553/1000): The Invention of Wings
# ✔ PRICE FOUND → ISBN 9780143121701
#
# Processing (554/1000): The Hobbit (Middle-Earth Universe)
#
# Processing (555/1000): The Great Railway Bazaar
# ✔ PRICE FOUND → ISBN 9780618658947
# ✔ PRICE FOUND → ISBN 9780395207086
#
# Processing (556/1000): The Golden Compass (His Dark Materials #1)
#
# Processing (557/1000): The God Delusion
# ✔ PRICE FOUND → ISBN 9780618918249
#
# Processing (558/1000): The Girl You Left Behind (The Girl You Left Behind #1)
#
# Processing (559/1000): The Fellowship of the Ring (The Lord of the Rings #1)
#
# Processing (560/1000): The Collected Poems of W.B. Yeats (The Collected Works of W.B. Yeats #1)
#
# Processing (561/1000): The Barefoot Contessa Cookbook
#
# Processing (562/1000): Tell the Wolves I'm Home
# ✔ PRICE FOUND → ISBN 9780812982855
#
# Processing (563/1000): Ship Leaves Harbor: Essays on Travel by a Recovering Journeyman
#
# Processing (564/1000): Pride and Prejudice
# ✔ PRICE FOUND → ISBN 9781853260001
#
# Processing (565/1000): Musicophilia: Tales of Music and the Brain
#
# Processing (566/1000): Mere Christianity
# ✔ PRICE FOUND → ISBN 9780060652920
# ✔ PRICE FOUND → ISBN 9780802725752
#
# Processing (567/1000): Me Before You (Me Before You #1)
#
# Processing (568/1000): In the Woods (Dublin Murder Squad #1)
#
# Processing (569/1000): In Cold Blood
#
# Processing (570/1000): How to Stop Worrying and Start Living
# ✔ PRICE FOUND → ISBN 9780671349004
# BooksRun error for ISBN 9791220296410: 'list' object has no attribute 'get'
#
# Processing (571/1000): Give It Back
#
# Processing (572/1000): Girl, Interrupted
# ✔ PRICE FOUND → ISBN 9780679746041
#
# Processing (573/1000): Fun Home: A Family Tragicomic
#
# Processing (574/1000): Fruits Basket, Vol. 6 (Fruits Basket #6)
#
# Processing (575/1000): Deception Point
# ✔ PRICE FOUND → ISBN 9781982122355
#
# Processing (576/1000): Death Note, Vol. 6: Give-and-Take (Death Note #6)
#
# Processing (577/1000): Catherine the Great: Portrait of a Woman
#
# Processing (578/1000): Better Homes and Gardens New Cook Book
# ✔ PRICE FOUND → ISBN 9780696224034
#
# Processing (579/1000): An Unquiet Mind: A Memoir of Moods and Madness
#
# Processing (580/1000): A Year in Provence (Provence #1)
# ✔ PRICE FOUND → ISBN 9780140296037
#
# Processing (581/1000): World Without End (The Pillars of the Earth #2)
#
# Processing (582/1000): Will Grayson, Will Grayson (Will Grayson, Will Grayson)
#
# Processing (583/1000): Why Save the Bankers?: And Other Essays on Our Economic and Political Crisis
#
# Processing (584/1000): Where She Went (If I Stay #2)
#
# Processing (585/1000): What If?: Serious Scientific Answers to Absurd Hypothetical Questions
#
# Processing (586/1000): Two Summers
#
# Processing (587/1000): This Is Your Brain on Music: The Science of a Human Obsession
#
# Processing (588/1000): The Secret Garden
# ✔ PRICE FOUND → ISBN 9780486280240
#
# Processing (589/1000): The Raven King (The Raven Cycle #4)
#
# Processing (590/1000): The Raven Boys (The Raven Cycle #1)
#
# Processing (591/1000): The Power Greens Cookbook: 140 Delicious Superfood Recipes
#
# Processing (592/1000): The Metamorphosis
# BooksRun error for ISBN 9798507840892: 'list' object has no attribute 'get'
#
# Processing (593/1000): The Mathews Men: Seven Brothers and the War Against Hitler's U-boats
#
# Processing (594/1000): The Little Paris Bookshop
# ✔ PRICE FOUND → ISBN 9780553418798
#
# Processing (595/1000): The Hiding Place
# ✔ PRICE FOUND → ISBN 9780800794057
# ✔ PRICE FOUND → ISBN 9780553256697
#
# Processing (596/1000): The Grand Design
#
# Processing (597/1000): The Firm
# ✔ PRICE FOUND → ISBN 9780440211457
# ✔ PRICE FOUND → ISBN 9780440245926
# ✔ PRICE FOUND → ISBN 9780385470476
#
# Processing (598/1000): The Fault in Our Stars
# ✔ PRICE FOUND → ISBN 9780525478812
#
# Processing (599/1000): The False Prince (The Ascendance Trilogy #1)
#
# Processing (600/1000): The Expatriates
# ✔ PRICE FOUND → ISBN 9780770435721
#
# Processing (601/1000): The Dream Thieves (The Raven Cycle #2)
#
# Processing (602/1000): The Darkest Corners
# ✔ PRICE FOUND → ISBN 9780553521450
# BooksRun error for ISBN 9798754552593: 'list' object has no attribute 'get'
#
# Processing (603/1000): The Crossover
# ✔ PRICE FOUND → ISBN 9780544107717
#
# Processing (604/1000): The 5th Wave (The 5th Wave #1)
#
# Processing (605/1000): Tell the Wind and Fire
# ✔ PRICE FOUND → ISBN 9780440159636
#
# Processing (606/1000): Tell Me Three Things
# ✔ PRICE FOUND → ISBN 9780553535679
#
# Processing (607/1000): Talking to Girls About Duran Duran: One Young Man's Quest for True Love and a Cooler Haircut
#
# Processing (608/1000): Siddhartha
#
# Processing (609/1000): Shiver (The Wolves of Mercy Falls #1)
#
# Processing (610/1000): Remember Me?
#
# Processing (611/1000): Red Dragon (Hannibal Lecter #1)
#
# Processing (612/1000): Peak: Secrets from the New Science of Expertise
#
# Processing (613/1000): My Mother Was Nuts
#
# Processing (614/1000): Mexican Today: New and Rediscovered Recipes for Contemporary Kitchens
#
# Processing (615/1000): Maybe Something Beautiful: How Art Transformed a Neighborhood
#
# Processing (616/1000): Lola and the Boy Next Door (Anna and the French Kiss #2)
#
# Processing (617/1000): Logan Kade (Fallen Crest High #5.5)
#
# Processing (618/1000): Last One Home (New Beginnings #1)
#
# ...
# ✔ PRICE FOUND → ISBN 9780375831003
#
# Processing (769/1000): The Book of Basketball: The NBA According to The Sports Guy
#
# Processing (770/1000): The Blind Side: Evolution of a Game
#
# Processing (771/1000): The Autobiography of Malcolm X
# ✔ PRICE FOUND → ISBN 9780345350688
#
# Processing (772/1000): The Art of Simple Food: Notes, Lessons, and Recipes from a Delicious Revolution
#
# Processing (773/1000): The Art of Fielding
# ✔ PRICE FOUND → ISBN 9780316126694
#
# Processing (774/1000): Surely You're Joking, Mr. Feynman!: Adventures of a Curious Character
#
# Processing (775/1000): Stiff: The Curious Lives of Human Cadavers
# ✔ PRICE FOUND → ISBN 9780393324822
#
# Processing (776/1000): Spilled Milk: Based on a True Story
#
# Processing (777/1000): Something Borrowed (Darcy & Rachel #1)
#
# Processing (778/1000): Something Blue (Darcy & Rachel #2)
#
# Processing (779/1000): Soldier (Talon #3)
#
# Processing (780/1000): Shopaholic & Baby (Shopaholic #5)
#
# Processing (781/1000): Seven Days in the Art World
# ✔ PRICE FOUND → ISBN 9780393067224
#
# Processing (782/1000): Seven Brief Lessons on Physics
# ✔ PRICE FOUND → ISBN 9780399184413
#
# Processing (783/1000): Scarlet (The Lunar Chronicles #2)
#
# Processing (784/1000): Sarah's Key
# ✔ PRICE FOUND → ISBN 9780312370831
#
# Processing (785/1000): Saga, Volume 3 (Saga (Collected Editions) #3)
#
# Processing (786/1000): Running with Scissors
#
# Processing (787/1000): Rogue Lawyer (Rogue Lawyer #1)
#
# Processing (788/1000): Rise of the Rocket Girls: The Women Who Propelled Us, from Missiles to the Moon to Mars
#
# Processing (789/1000): Rework
# ✔ PRICE FOUND → ISBN 9780307463746
#
# Processing (790/1000): Reservations for Two
#
# Processing (791/1000): Red: The True Story of Red Riding Hood
# ✔ PRICE FOUND → ISBN 9780385755863
#
# Processing (792/1000): Ready Player One
# ✔ PRICE FOUND → ISBN 9780307887443
#
# Processing (793/1000): Quiet: The Power of Introverts in a World That Can't Stop Talking
#
# Processing (794/1000): Prodigy: The Graphic Novel (Legend: The Graphic Novel #2)
#
# Processing (795/1000): Persepolis: The Story of a Childhood (Persepolis #1-2)
#
# Processing (796/1000): Packing for Mars: The Curious Science of Life in the Void
# ✔ PRICE FOUND → ISBN 9780393339918
#
# Processing (797/1000): Outliers: The Story of Success
#
# Processing (798/1000): Original Fake
#
# Processing (799/1000): Orange Is the New Black
#
# Processing (800/1000): One for the Money (Stephanie Plum #1)
#
# Processing (801/1000): Notes from a Small Island (Notes From a Small Island #1)
#
# Processing (802/1000): Night (The Night Trilogy #1)
#
# Processing (803/1000): Neither Here nor There: Travels in Europe
#
# Processing (804/1000): Naked
#
# Processing (805/1000): Morning Star (Red Rising #3)
#
# Processing (806/1000): Miracles from Heaven: A Little Girl, Her Journey to Heaven, and Her Amazing Story of Healing
#
# Processing (807/1000): Midnight Riot (Peter Grant/ Rivers of London - books #1)
#
# Processing (808/1000): Me Talk Pretty One Day
#
# Processing (809/1000): Manuscript Found in Accra
# ✔ PRICE FOUND → ISBN 9780345805058
#
# Processing (810/1000): Lust & Wonder
# ✔ PRICE FOUND → ISBN 9780312342036
#
# Processing (811/1000): Lila (Gilead #3)
#
# Processing (812/1000): Life, the Universe and Everything (Hitchhiker's Guide to the Galaxy #3)
#
# Processing (813/1000): Life Without a Recipe
#
# Processing (814/1000): Life After Life
#
# Processing (815/1000): Letter to a Christian Nation
#
# Processing (816/1000): Let's Pretend This Never Happened: A Mostly True Memoir
# ✔ PRICE FOUND → ISBN 9780425261019
#
# Processing (817/1000): Legend (Legend #1)
#
# Processing (818/1000): Lean In: Women, Work, and the Will to Lead
#
# Processing (819/1000): Lamb: The Gospel According to Biff, Christ's Childhood Pal
#
# Processing (820/1000): Lady Renegades (Rebel Belle #3)
#
# Processing (821/1000): Jurassic Park (Jurassic Park #1)
#
# Processing (822/1000): It's Never Too Late to Begin Again: Discovering Creativity and Meaning at Midlife and Beyond
#
# Processing (823/1000): Is Everyone Hanging Out Without Me? (And Other Concerns)
# ✔ PRICE FOUND → ISBN 9780307886279
#
# Processing (824/1000): Into the Wild
#
# Processing (825/1000): Inferno (Robert Langdon #4)
#
# Processing (826/1000): In the Garden of Beasts: Love, Terror, and an American Family in Hitler's Berlin
#
# Processing (827/1000): If I Run (If I Run #1)
#
# Processing (828/1000): I've Got Your Number
# ✔ PRICE FOUND → ISBN 9780385342063
#
# Processing (829/1000): I Am Malala: The Girl Who Stood Up for Education and Was Shot by the Taliban
#
# Processing (830/1000): Hungry Girl Clean & Hungry: Easy All-Natural Recipes for Healthy Eating in the Real World
#
# Processing (831/1000): House of Lost Worlds: Dinosaurs, Dynasties, and the Story of Life on Earth
#
# Processing (832/1000): House of Leaves
#
# Processing (833/1000): Horrible Bear!
#
# Processing (834/1000): Holidays on Ice
#
# Processing (835/1000): Heir to the Sky
#
# Processing (836/1000): Green Eggs and Ham (Beginner Books B-16)
#
# Processing (837/1000): Grayson, Vol 3: Nemesis (Grayson #3)
#
# Processing (838/1000): Gratitude
#
# Processing (839/1000): Gone Girl
#
# Processing (840/1000): Golden (Heart of Dread #3)
#
# Processing (841/1000): Girl in the Blue Coat
# BooksRun error for ISBN 9798649804035: 'list' object has no attribute 'get'
#
# Processing (842/1000): Fruits Basket, Vol. 3 (Fruits Basket #3)
#
# Processing (843/1000): Friday Night Lights: A Town, a Team, and a Dream
#
# Processing (844/1000): Fire Bound (Sea Haven/Sisters of the Heart #5)
#
# Processing (845/1000): Fifty Shades Freed (Fifty Shades #3)
#
# Processing (846/1000): Fellside
#
# Processing (847/1000): Extreme Prey (Lucas Davenport #26)
#
# Processing (848/1000): Eragon (The Inheritance Cycle #1)
#
# Processing (849/1000): Eclipse (Twilight #3)
#
# Processing (850/1000): Dune (Dune #1)
#
# Processing (851/1000): Dracula
#
# Processing (852/1000): Do Androids Dream of Electric Sheep? (Blade Runner #1)
#
# Processing (853/1000): Disrupted: My Misadventure in the Start-Up Bubble
#
# Processing (854/1000): Dead Wake: The Last Crossing of the Lusitania
#
# Processing (855/1000): David and Goliath: Underdogs, Misfits, and the Art of Battling Giants
#
# Processing (856/1000): Darkfever (Fever #1)
#
# Processing (857/1000): Dark Places
# ✔ PRICE FOUND → ISBN 9781101902882
#
# Processing (858/1000): Crazy Rich Asians (Crazy Rich Asians #1)
#
# Processing (859/1000): Counting Thyme
#
# Processing (860/1000): Cosmos
# ✔ PRICE FOUND → ISBN 9780345539434
#
# Processing (861/1000): Civilization and Its Discontents
# ✔ PRICE FOUND → ISBN 9780486282534
#
# Processing (862/1000): Cinder (The Lunar Chronicles #1)
#
# Processing (863/1000): Catastrophic Happiness: Finding Joy in Childhood's Messy Years
#
# Processing (864/1000): Career of Evil (Cormoran Strike #3)
#
# Processing (865/1000): Breaking Dawn (Twilight #4)
#
# Processing (866/1000): Brave Enough
# ✔ PRICE FOUND → ISBN 9781101946909
#
# Processing (867/1000): Boy Meets Boy
# ✔ PRICE FOUND → ISBN 9780375832994
#
# Processing (868/1000): Born to Run: A Hidden Tribe, Superathletes, and the Greatest Race the World Has Never Seen
#
# Processing (869/1000): Blink: The Power of Thinking Without Thinking
#
# Processing (870/1000): Black Flags: The Rise of ISIS
#
# Processing (871/1000): Black Butler, Vol. 1 (Black Butler #1)
#
# Processing (872/1000): Big Little Lies
# ✔ PRICE FOUND → ISBN 9781524754686
#
# Processing (873/1000): Between Shades of Gray
# ✔ PRICE FOUND → ISBN 9780142420591
# ✔ PRICE FOUND → ISBN 9780593404850
#
# Processing (874/1000): Best of My Love (Fool's Gold #20)
#
# Processing (875/1000): Beowulf
#
# Processing (876/1000): Beautiful Creatures (Caster Chronicles #1)
#
# Processing (877/1000): Awkward
#
# Processing (878/1000): Ash
#
# Processing (879/1000): Are We There Yet?
#
# Processing (880/1000): Are We Smart Enough to Know How Smart Animals Are?
# ✔ PRICE FOUND → ISBN 9780393353662
#
# Processing (881/1000): Annie on My Mind
#
# Processing (882/1000): And Then There Were None
# ✔ PRICE FOUND → ISBN 9780573616396
#
# Processing (883/1000): A Walk in the Woods: Rediscovering America on the Appalachian Trail
#
# Processing (884/1000): A Visit from the Goon Squad
# ✔ PRICE FOUND → ISBN 9780307592835
#
# Processing (885/1000): A Storm of Swords (A Song of Ice and Fire #3)
#
# Processing (886/1000): A Heartbreaking Work of Staggering Genius
#
# Processing (887/1000): 8 Keys to Mental Health Through Exercise
#
# Processing (888/1000): #GIRLBOSS
#
# Processing (889/1000): The Suffragettes (Little Black Classics, #96)
#
# Processing (890/1000): The Sense of an Ending
#
# Processing (891/1000): The Sandman, Vol. 2: The Doll's House (The Sandman (volumes) #2)
# ✔ PRICE FOUND → ISBN 9781401285067
#
# Processing (892/1000): The Course of Love
#
# Processing (893/1000): Sugar Rush (Offensive Line #2)
#
# Processing (894/1000): Saga, Volume 2 (Saga (Collected Editions) #2)
#
# Processing (895/1000): Run, Spot, Run: The Ethics of Keeping Pets
#
# Processing (896/1000): New Moon (Twilight #2)
#
# Processing (897/1000): Life
#
# Processing (898/1000): Kindle Paperwhite User's Guide
#
# Processing (899/1000): H is for Hawk
#
# Processing (900/1000): Girl Online On Tour (Girl Online #2)
#
# Processing (901/1000): Fruits Basket, Vol. 2 (Fruits Basket #2)
#
# Processing (902/1000): Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Unofficial Minecraft Book)
#
# Processing (903/1000): Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)
#
# Processing (904/1000): While You Were Mine
# BooksRun error for ISBN 9798634036953: 'list' object has no attribute 'get'
#
# Processing (905/1000): Where Lightning Strikes (Bleeding Stars #3)
#
# Processing (906/1000): When I'm Gone
# ✔ PRICE FOUND → ISBN 9781695914407
# BooksRun error for ISBN 9798282108392: 'list' object has no attribute 'get'
#
# Processing (907/1000): Ways of Seeing
#
# Processing (908/1000): Vampire Knight, Vol. 1 (Vampire Knight #1)
#
# Processing (909/1000): Vampire Girl (Vampire Girl #1)
#
# Processing (910/1000): Twenty Love Poems and a Song of Despair
# ✔ PRICE FOUND → ISBN 9780140186482
#
# Processing (911/1000): Travels with Charley: In Search of America
# ✔ PRICE FOUND → ISBN 9780140053203
# ✔ PRICE FOUND → ISBN 9780140187410
#
# Processing (912/1000): Three Wishes (River of Time: California #1)
#
# Processing (913/1000): This One Moment (Pushing Limits #1)
#
# Processing (914/1000): The Zombie Room
#
# Processing (915/1000): The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The Divine)
#
# Processing (916/1000): The Tumor
#
# Processing (917/1000): The Story of Hong Gildong
# ✔ PRICE FOUND → ISBN 9780143107699
#
# Processing (918/1000): The Silent Wife
#
# Processing (919/1000): The Silent Twin (Detective Jennifer Knight #3)
#
# Processing (920/1000): The Selfish Gene
# ✔ PRICE FOUND → ISBN 9780198788607
#
# Processing (921/1000): The Secret Healer
# ✔ PRICE FOUND → ISBN 9781503953864
#
# Processing (922/1000): The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) #1)
#
# Processing (923/1000): The Republic
#
# Processing (924/1000): The Odyssey
#
# Processing (925/1000): The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)
#
# Processing (926/1000): The Nicomachean Ethics
#
# Processing (927/1000): The Name of the Wind (The Kingkiller Chronicle #1)
#
# Processing (928/1000): The Mirror & the Maze (The Wrath and the Dawn #1.5)
#
# Processing (929/1000): The Little Prince
# ✔ PRICE FOUND → ISBN 9780156012195
#
# Processing (930/1000): The Light of the Fireflies
#
# Processing (931/1000): The Last Girl (The Dominion Trilogy #1)
#
# Processing (932/1000): The Iliad
#
# Processing (933/1000): The Hook Up (Game On #1)
#
# Processing (934/1000): The Haters
#
# Processing (935/1000): The Girl You Lost
#
# Processing (936/1000): The Girl In The Ice (DCI Erika Foster #1)
#
# Processing (937/1000): The End of the Jesus Era (An Investigation #1)
#
# Processing (938/1000): The Edge of Reason (Bridget Jones #2)
#
# Processing (939/1000): The Complete Maus (Maus #1-2)
#
# Processing (940/1000): The Communist Manifesto
# ✔ PRICE FOUND → ISBN 9780671678814
# BooksRun error for ISBN 9798888900451: 'list' object has no attribute 'get'
#
# Processing (941/1000): The Bhagavad Gita
# ✔ PRICE FOUND → ISBN 9781586380199
#
# Processing (942/1000): The Bette Davis Club
#
# Processing (943/1000): The Art of Not Breathing
# BooksRun error for ISBN 9798282211047: 'list' object has no attribute 'get'
#
# Processing (944/1000): Taking Shots (Assassins #1)
#
# Processing (945/1000): Starlark
#
# Processing (946/1000): Skip Beat!, Vol. 01 (Skip Beat! #1)
#
# Processing (947/1000): Sister Sable (The Mad Queen #1)
#
# Processing (948/1000): Shatter Me (Shatter Me #1)
#
# Processing (949/1000): Shameless
# BooksRun error for ISBN 9798201742201: 'list' object has no attribute 'get'
#
# Processing (950/1000): Shadow Rites (Jane Yellowrock #10)
#
# Processing (951/1000): Settling the Score (The Summer Games #1)
#
# Processing (952/1000): Sense and Sensibility
#
# Processing (953/1000): Saga, Volume 1 (Saga (Collected Editions) #1)
#
# Processing (954/1000): Rhythm, Chord & Malykhin
#
# Processing (955/1000): Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)
#
# Processing (956/1000): Paradise Lost (Paradise #1)
#
# Processing (957/1000): Paper Girls, Vol. 1 (Paper Girls #1-5)
#
# Processing (958/1000): Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1)
#
# Processing (959/1000): Origins (Alphas 0.5)
#
# Processing (960/1000): One Second (Seven #7)
#
# Processing (961/1000): On the Road (Duluoz Legend)
#
# Processing (962/1000): Old Records Never Die: One Man's Quest for His Vinyl and His Past
#
# Processing (963/1000): Off Sides (Off #1)
#
# Processing (964/1000): Of Mice and Men
# BooksRun error for ISBN 9798587946361: 'list' object has no attribute 'get'
#
# Processing (965/1000): Myriad (Prentor #1)
#
# Processing (966/1000): My Perfect Mistake (Over the Top #1)
#
# Processing (967/1000): Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)
#
# Processing (968/1000): Meditations
#
# Processing (969/1000): Matilda
#
# Processing (970/1000): Lost Among the Living
# ✔ PRICE FOUND → ISBN 9780451476197
#
# Processing (971/1000): Lord of the Flies
# ✔ PRICE FOUND → ISBN 9780399529207
#
# Processing (972/1000): Listen to Me (Fusion #1)
#
# Processing (973/1000): Kitchens of the Great Midwest
# ✔ PRICE FOUND → ISBN 9780525429142
#
# Processing (974/1000): Jane Eyre
# ✔ PRICE FOUND → ISBN 9780141441146
#
# Processing (975/1000): Imperfect Harmony
#
# Processing (976/1000): Icing (Aces Hockey #2)
#
# Processing (977/1000): Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)
#
# Processing (978/1000): Having the Barbarian's Baby (Ice Planet Barbarians #7.5)
#
# Processing (979/1000): Giant Days, Vol. 1 (Giant Days #1-4)
#
# Processing (980/1000): Fruits Basket, Vol. 1 (Fruits Basket #1)
#
# Processing (981/1000): Frankenstein
# ✔ PRICE FOUND → ISBN 9780486282114
#
# Processing (982/1000): Forever Rockers (The Rocker #12)
#
# Processing (983/1000): Fighting Fate (Fighting #6)
#
# Processing (984/1000): Emma
#
# Processing (985/1000): Eat, Pray, Love
# ✔ PRICE FOUND → ISBN 9780143118428
# BooksRun error for ISBN 9798668111909: 'list' object has no attribute 'get'
#
# Processing (986/1000): Deep Under (Walker Security #1)
#
# Processing (987/1000): Choosing Our Religion: The Spiritual Lives of America's Nones
#
# Processing (988/1000): Charlie and the Chocolate Factory (Charlie Bucket #1)
# ✔ PRICE FOUND → ISBN 9780143106333
#
# Processing (989/1000): Charity's Cross (Charles Towne Belles #4)
#
# Processing (990/1000): Bright Lines
# ✔ PRICE FOUND → ISBN 9780143123132
# ✔ PRICE FOUND → ISBN 9781401952532
#
# Processing (991/1000): Bridget Jones's Diary (Bridget Jones #1)
# ✔ PRICE FOUND → ISBN 9780140280098
#
# Processing (992/1000): Bounty (Colorado Mountain #7)
#
# Processing (993/1000): Blood Defense (Samantha Brinkman #1)
#
# Processing (994/1000): Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)
#
# Processing (995/1000): Beyond Good and Evil
# ✔ PRICE FOUND → ISBN 9780140449235
#
# Processing (996/1000): Alice in Wonderland (Alice's Adventures in Wonderland #1)
#
# Processing (997/1000): Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)
#
# Processing (998/1000): A Spy's Devotion (The Regency Spies of London #1)
#
# Processing (999/1000): 1st to Die (Women's Murder Club #1)
#
# Processing (1000/1000): 1,000 Places to See Before You Die
# ✔ PRICE FOUND → ISBN 9780761156864
#
# ✅ Finished!
# ✅ Total books with prices: 191
# ✅ CSV saved: booksrun_price_comparison.csv
